# %% [markdown]
# ## Загрузка набора данных

# %% [markdown]
# ### Загрузка пакетов

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm
from scipy import stats
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import LassoCV
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from statsmodels.graphics.gofplots import qqplot

# %% [markdown]
# ### Функция оптимизации памяти

# %%
def optimizing_df(df):
    for col in df.columns:
        if df[col].dtypes.kind in 'iu':
            df[col] = pd.to_numeric(df[col], downcast='unsigned' if df[col].min() >= 0 else 'integer')
        elif df[col].dtypes.kind in 'fc':
            df[col] = pd.to_numeric(df[col], downcast='float')
        elif df[col].dtypes.kind == 'O':
            if len(df[col].unique()) / len(df[col]) < 0.5:
                df[col] = df[col].astype('category')
    return df

# %% [markdown]
# ### Загрузка данных и их предварительный анализ

# %%
train = pd.read_csv('Data/train.csv')
test = pd.read_csv('Data/test.csv')
print("Данные загружены!")
# Out:
# Данные загружены!

# %%
print(f"Train:\t{train.shape[0]}\t sales and {train.shape[1]} features")
print(f'Test:\t{test.shape[0]}\t sales and {test.shape[1]} features')
# Out:
# Train:	10000	 sales and 20 features
# Test:	5000	 sales and 19 features

# %%
train.head()
# Out:
#       Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0  14038          35    2.0  47.981561   29.442751            6.0      7
# 1  15053          41    3.0  65.683640   40.049543            8.0      7
# 2   4765          53    2.0  44.947953   29.197612            0.0      8
# 3   5809          58    2.0  53.352981   52.731512            9.0      8
# 4  10783          99    1.0  39.649192   23.776169            7.0     11
#
#    HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 0         9.0       1969   0.089040         B         B        33      7976
# 1         9.0       1978   0.000070         B         B        46     10309
# 2        12.0       1968   0.049637         B         B        34      7759
# 3        17.0       1977   0.437885         B         B        23      5735
# 4        12.0       1976   0.012339         B         B        35      5776
#
#    Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2          Price
# 0         5           NaN            0       11       B  184966.930730
# 1         1         240.0            1       16       B  300009.450063
# 2         0         229.0            1        3       B  220925.908524
# 3         3        1084.0            0        5       B  175616.227217
# 4         1        2078.0            2        4       B  150226.531644

# %%
test.head()
# Out:
#       Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0    725          58    2.0  49.882643   33.432782            6.0      6
# 1  15856          74    2.0  69.263183         NaN            1.0      6
# 2   5480         190    1.0  13.597819   15.948246           12.0      2
# 3  15664          47    2.0  73.046609   51.940842            9.0     22
# 4  14275          27    1.0  47.527111   43.387569            1.0     17
#
#    HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 0        14.0       1972   0.310199         B         B        11      2748
# 1         1.0       1977   0.075779         B         B         6      1437
# 2         5.0       1909   0.000000         B         B        30      7538
# 3        22.0       2007   0.101872         B         B        23      4583
# 4        17.0       2017   0.072158         B         B         2       629
#
#    Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 0         1           NaN            0        0       B
# 1         3           NaN            0        2       B
# 2        87        4702.0            5        5       B
# 3         3           NaN            3        3       B
# 4         1           NaN            0        0       A

# %%
train.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             10000 non-null  int64
#  1   DistrictId     10000 non-null  int64
#  2   Rooms          10000 non-null  float64
#  3   Square         10000 non-null  float64
#  4   LifeSquare     7887 non-null   float64
#  5   KitchenSquare  10000 non-null  float64
#  6   Floor          10000 non-null  int64
#  7   HouseFloor     10000 non-null  float64
#  8   HouseYear      10000 non-null  int64
#  9   Ecology_1      10000 non-null  float64
#  10  Ecology_2      10000 non-null  object
#  11  Ecology_3      10000 non-null  object
#  12  Social_1       10000 non-null  int64
#  13  Social_2       10000 non-null  int64
#  14  Social_3       10000 non-null  int64
#  15  Healthcare_1   5202 non-null   float64
#  16  Helthcare_2    10000 non-null  int64
#  17  Shops_1        10000 non-null  int64
#  18  Shops_2        10000 non-null  object
#  19  Price          10000 non-null  float64
# dtypes: float64(8), int64(9), object(3)
# memory usage: 3.0 MB

# %%
test.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             5000 non-null   int64
#  1   DistrictId     5000 non-null   int64
#  2   Rooms          5000 non-null   float64
#  3   Square         5000 non-null   float64
#  4   LifeSquare     3959 non-null   float64
#  5   KitchenSquare  5000 non-null   float64
#  6   Floor          5000 non-null   int64
#  7   HouseFloor     5000 non-null   float64
#  8   HouseYear      5000 non-null   int64
#  9   Ecology_1      5000 non-null   float64
#  10  Ecology_2      5000 non-null   object
#  11  Ecology_3      5000 non-null   object
#  12  Social_1       5000 non-null   int64
#  13  Social_2       5000 non-null   int64
#  14  Social_3       5000 non-null   int64
#  15  Healthcare_1   2623 non-null   float64
#  16  Helthcare_2    5000 non-null   int64
#  17  Shops_1        5000 non-null   int64
#  18  Shops_2        5000 non-null   object
# dtypes: float64(7), int64(9), object(3)
# memory usage: 1.4 MB

# %% [markdown]
# ### Оптимизация использования памяти

# %%
train['Rooms'] = train['Rooms'].astype('int64')
test['Rooms'] = test['Rooms'].astype('int64')

# %%
train['HouseFloor'] = train['HouseFloor'].astype('int64')
test['HouseFloor'] = test['HouseFloor'].astype('int64')

# %%
train = optimizing_df(train)
test = optimizing_df(test)

# %%
train.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             10000 non-null  uint16
#  1   DistrictId     10000 non-null  uint8
#  2   Rooms          10000 non-null  uint8
#  3   Square         10000 non-null  float32
#  4   LifeSquare     7887 non-null   float32
#  5   KitchenSquare  10000 non-null  float32
#  6   Floor          10000 non-null  uint8
#  7   HouseFloor     10000 non-null  uint8
#  8   HouseYear      10000 non-null  uint32
#  9   Ecology_1      10000 non-null  float32
#  10  Ecology_2      10000 non-null  category
#  11  Ecology_3      10000 non-null  category
#  12  Social_1       10000 non-null  uint8
#  13  Social_2       10000 non-null  uint16
#  14  Social_3       10000 non-null  uint8
#  15  Healthcare_1   5202 non-null   float32
#  16  Helthcare_2    10000 non-null  uint8
#  17  Shops_1        10000 non-null  uint8
#  18  Shops_2        10000 non-null  category
#  19  Price          10000 non-null  float32
# dtypes: category(3), float32(6), uint16(2), uint32(1), uint8(8)
# memory usage: 420.7 KB

# %%
test.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             5000 non-null   uint16
#  1   DistrictId     5000 non-null   uint8
#  2   Rooms          5000 non-null   uint8
#  3   Square         5000 non-null   float32
#  4   LifeSquare     3959 non-null   float32
#  5   KitchenSquare  5000 non-null   float32
#  6   Floor          5000 non-null   uint8
#  7   HouseFloor     5000 non-null   uint8
#  8   HouseYear      5000 non-null   uint16
#  9   Ecology_1      5000 non-null   float32
#  10  Ecology_2      5000 non-null   category
#  11  Ecology_3      5000 non-null   category
#  12  Social_1       5000 non-null   uint8
#  13  Social_2       5000 non-null   uint16
#  14  Social_3       5000 non-null   uint8
#  15  Healthcare_1   2623 non-null   float32
#  16  Helthcare_2    5000 non-null   uint8
#  17  Shops_1        5000 non-null   uint8
#  18  Shops_2        5000 non-null   category
# dtypes: category(3), float32(5), uint16(3), uint8(8)
# memory usage: 181.4 KB

# %% [markdown]
# ### Проверка данных

# %%
all_data = pd.concat((train, test), sort=False).reset_index(drop=True)
all_data.drop(['Price'], axis=1, inplace=True)

# %%
all_data.describe().transpose()
# Out:
#                  count         mean            std          min          25%  \
# Id             15000.0  8393.136933    4850.111673     0.000000  4188.750000
# DistrictId     15000.0    50.693600      43.786257     0.000000    20.000000
# Rooms          15000.0     1.897000       0.839229     0.000000     1.000000
# Square         15000.0    56.360546      20.423899     1.136859    41.814370
# LifeSquare     11846.0    36.851711      71.120201     0.333490    22.896130
# KitchenSquare  15000.0     6.174467      24.017548     0.000000     1.000000
# Floor          15000.0     8.561800       5.323113     1.000000     4.000000
# HouseFloor     15000.0    12.606600       6.780165     0.000000     9.000000
# HouseYear      15000.0  3321.575067  163707.780381  1908.000000  1974.000000
# Ecology_1      15000.0     0.119195       0.119371     0.000000     0.017647
# Social_1       15000.0    24.769267      17.532278     0.000000     6.000000
# Social_2       15000.0  5370.404933    4013.364403   168.000000  1564.000000
# Social_3       15000.0     8.113667      23.841946     0.000000     0.000000
# Healthcare_1    7825.0  1144.162476    1029.307373     0.000000   350.000000
# Helthcare_2    15000.0     1.319467       1.489012     0.000000     0.000000
# Shops_1        15000.0     4.235133       4.796545     0.000000     1.000000
#
#                        50%           75%           max
# Id             8378.500000  12594.250000  1.679800e+04
# DistrictId       37.000000     75.000000  2.120000e+02
# Rooms             2.000000      2.000000  1.900000e+01
# Square           52.645758     66.036606  6.410652e+02
# LifeSquare       32.822811     45.144627  7.480592e+03
# KitchenSquare     6.000000      9.000000  2.014000e+03
# Floor             7.000000     12.000000  7.800000e+01
# HouseFloor       12.000000     17.000000  1.170000e+02
# HouseYear      1977.000000   2001.000000  2.005201e+07
# Ecology_1         0.075424      0.195781  5.218670e-01
# Social_1         25.000000     36.000000  7.400000e+01
# Social_2       5285.000000   7287.000000  1.908300e+04
# Social_3          2.000000      5.000000  1.410000e+02
# Healthcare_1    900.000000   1548.000000  4.849000e+03
# Helthcare_2       1.000000      2.000000  6.000000e+00
# Shops_1           3.000000      6.000000  2.300000e+01

# %% [markdown]
# #### Исправление количества комнат

# %%
all_data.loc[all_data['Rooms'] > 6]
# Out:
#           Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 377     5927          57     10  59.056976   36.223072           10.0     22
# 1454    8491           1     19  42.006046   21.779287            7.0     17
# 8849   14865           9     10  60.871265   38.420681           10.0      3
# 13398   1435         111     17  52.866108   32.528343            8.0     15
#
#        HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 377            22       2002   0.090799         B         B        74
# 1454           17       2014   0.007122         B         B         1
# 8849            2       1994   0.161532         B         B        25
# 13398          17       1987   0.093443         B         B        23
#
#        Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 377       19083         2           NaN            5       15       B
# 1454        264         0           NaN            0        1       B
# 8849       5648         1          30.0            2        4       B
# 13398      4635         5        3300.0            2        4       B

# %%
all_data.loc[all_data['Rooms'] == 0]
# Out:
#           Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 1397   12638          27      0  138.427689  136.215500            0.0      4
# 1981    7917          27      0  212.932358  211.231125            0.0      2
# 2269    7317          27      0   41.790882         NaN            0.0     13
# 3911     770          28      0   49.483501         NaN            0.0     16
# 4366     456           6      0   81.491447         NaN            0.0      4
# 4853    3224          27      0    2.377248    0.873147            0.0      1
# 6149    3159          88      0   38.697117   19.345131            9.0      9
# 8834    9443          27      0   87.762619   85.125473            0.0      5
# 12406   3343          58      0  116.824203  113.692421            0.0      3
# 12524  10729          27      0   76.345154   42.820797           12.0     14
#
#        HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1397            3       2016   0.075424         B         B        11
# 1981            3       2008   0.211401         B         B         9
# 2269            0       1977   0.211401         B         B         9
# 3911            0       2015   0.118537         B         B        30
# 4366            0       1977   0.243205         B         B         5
# 4853            0       1977   0.017647         B         B         2
# 6149           16       1982   0.127376         B         B        43
# 8834           15       1977   0.211401         B         B         9
# 12406           3       1977   0.437885         B         B        23
# 12524           0       1977   0.017647         B         B         2
#
#        Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 1397       3097         0           NaN            0        0       B
# 1981       1892         0           NaN            0        1       B
# 2269       1892         0           NaN            0        1       B
# 3911       6207         1        1183.0            1        0       B
# 4366       1564         0         540.0            0        0       B
# 4853        469         0           NaN            0        0       B
# 6149       8429         3           NaN            3        9       B
# 8834       1892         0           NaN            0        1       B
# 12406      5735         3        1084.0            0        5       B
# 12524       469         0           NaN            0        0       B

# %%
def df_fix_room(df):
    info_by_district_id = df.groupby(['DistrictId', 'HouseYear'], as_index=False).agg({'Rooms': 'sum', 'Square': 'sum'}).rename(columns={'Rooms': 'sum_roos_dr', 'Square': 'sum_square_dr'})
    info_by_district_id['mean_square_per_room_in_dr'] = info_by_district_id['sum_square_dr'] / info_by_district_id['sum_roos_dr']
    info_by_district_id.drop(['sum_square_dr', 'sum_roos_dr'], axis=1, inplace=True)
    df = pd.merge(df, info_by_district_id, on=['DistrictId', 'HouseYear'], how='left')
    df['mean_square_per_room_in_dr'] = df['mean_square_per_room_in_dr'].fillna(df['mean_square_per_room_in_dr'].mean())
    df.loc[df['Rooms'] > 6, 'Rooms'] = (df.loc[df['Rooms'] > 6, 'Square'] // df.loc[df['Rooms'] > 6, 'mean_square_per_room_in_dr']).astype('int')
    df.loc[df['Rooms'] == 0, 'Rooms'] = (df.loc[df['Rooms'] == 0, 'Square'] // df.loc[df['Rooms'] == 0, 'mean_square_per_room_in_dr']).astype('int')
    df.loc[df['Rooms'] == 0, 'Rooms'] = 1
    return df

# %% [markdown]
# #### Исправление площади

# %%
all_data.loc[all_data['Square'] > 200].nlargest(20, 'Square')
# Out:
#           Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 6977   11602          30      2  641.065186  638.163208           10.0     20
# 4262      28           9      2  604.705994         NaN            1.0     17
# 4690    2307         102      1  409.425171  410.639740           10.0      4
# 1982    5548          86      5  275.645294  233.949310           26.0     12
# 13217   4058          27      6  223.453690  104.113556           16.0      2
# 13909   1397          76      3  221.138763  118.055344            4.0     32
# 1981    7917          27      0  212.932358  211.231125            0.0      2
# 9910   16568          27      4  200.334534  201.627365           25.0      1
#
#        HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 6977           19       2019   0.000078         B         B        22
# 4262           18       1977   0.161532         B         B        25
# 4690            4       2016   0.238617         B         B        26
# 1982           37       2011   0.161976         B         A        31
# 13217           2       2017   0.041116         B         B        53
# 13909          48       2011   0.000000         B         B         7
# 1981            3       2008   0.211401         B         B         9
# 9910            2       2013   0.041116         B         B        53
#
#        Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 6977       6398       141        1046.0            3       23       B
# 4262       5648         1          30.0            2        4       B
# 4690       3889         6         705.0            3        6       B
# 1982       7010         5        4508.0            3        7       B
# 13217     14892         4           NaN            1        4       B
# 13909      1660        39        1786.0            1        5       B
# 1981       1892         0           NaN            0        1       B
# 9910      14892         4           NaN            1        4       B

# %%
sns.histplot(all_data['Square'], kde=True, stat='density', label='Square distribution')

mu, sigma = norm.fit(all_data['Square'])

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, sigma)
plt.plot(x, p, 'k', linewidth=2, label=f'Normal dist. ($\mu=$ {mu:.2f} and $\sigma=$ {sigma:.2f})')

plt.ylabel('Frequency')
plt.title('Square distribution')
plt.legend()

# QQ-plot
fig = plt.figure()
qqplot(all_data['Square'], line='s')
plt.show()

# %%
def df_fix_square_manual(df):
    df.loc[df['Square'] > 400, 'Square'] = df.loc[df['Square'] > 400, 'Square'] / 10
    return df

# %%
def df_fix_square(df):
    info_by_district_id = df.groupby(['DistrictId', 'Rooms', 'HouseYear'], as_index=False).agg(
        {'Square': 'mean'}).rename(
        columns={'Square': 'mean_square_rooms_dr'})

    df = pd.merge(df, info_by_district_id, on=[
        'DistrictId', 'Rooms', 'HouseYear'], how='left')

    df.loc[abs(df['Square'] - df['mean_square_rooms_dr']) > 2 * sigma, 'Square'] \
        = df.loc[abs(df['Square'] - df['mean_square_rooms_dr']) > 2 * sigma, 'Rooms'] \
        * df.loc[abs(df['Square'] - df['mean_square_rooms_dr']) > 2 * sigma, 'mean_square_per_room_in_dr']
    return df

# %%
def prepare_lifesquare(df):
    df.loc[df['Square'] < df['LifeSquare'],
           'LifeSquare'] = df.loc[df['Square'] < df['LifeSquare'], 'Square']
    return df


def fillna_life_square(df):
    df['LifeSquare'] = df['LifeSquare'].fillna(df['LifeSquare'].mean())
    return df

# %% [markdown]
# #### Исправление года постройки дома

# %%
all_data.loc[all_data['HouseYear'] > 2020]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 1497  10814         109      1  37.265072   20.239714            9.0      9
# 4189  11607         147      2  44.791836   28.360394            5.0      4
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1497          12   20052011   0.136330         B         B        30
# 4189           9       4968   0.319809         B         B        25
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 1497      6141        10         262.0            3        6       B
# 4189      4756        16        2857.0            5        8       B

# %%
def df_fix_house_year_manual(df):
    df.loc[df['HouseYear'] == 20052011, 'HouseYear'] = int((2005 + 2011) / 2)
    df.loc[df['HouseYear'] == 4968, 'HouseYear'] = 1968
    return df

# %% [markdown]
# ## Обработка данных

# %% [markdown]
# ### Загрузка пакетов

# %%
import numpy as np

from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering

# %% [markdown]
# ### Целевая переменная¶

# %% [markdown]
# #### Нормальное распределение целевой переменной

# %%
sns.histplot(train['Price'], kde=True)

mu, sigma = norm.fit(train['Price'])

print(f'mu = {mu:.2f} and sigma = {sigma:.2f}')

plt.legend(
    [f'Normal dist. ($\mu=$ {mu:.2f} and $\sigma=$ {sigma:.2f} )'], loc='best')
plt.xlabel('Стоимость')
plt.ylabel('Частота')
plt.title('Распределение цен')

# QQ-plot
fig = plt.figure()
res = stats.probplot(train['Price'], plot=plt)
plt.xlabel('Теоретические квантили')
plt.ylabel('Эмпирические квантили')
plt.title('QQ-график для Price')
plt.show()

fig = plt.figure()
qqplot(all_data['Square'], line='s')
plt.xlabel('Теоретические квантили')
plt.ylabel('Эмпирические квантили')
plt.title('QQ-график для Square')
plt.show()
# Out:
# mu = 214138.86 and sigma = 92867.65

# %% [markdown]
# #### Логарифмическое распределение целевой переменной

# %%
price_log = np.log1p(train['Price'])
sns.histplot(price_log, kde=True)

mu, sigma = norm.fit(train['Price'])

print(f'mu = {mu:.2f} and sigma = {sigma:.2f}')

plt.legend(
    [f'Normal dist. ($\mu=$ {mu:.2f} and $\sigma=$ {sigma:.2f} )'], loc='best')
plt.xlabel('Стоимость')
plt.ylabel('Частота')
plt.title('Распределение цен')

# QQ-plot
fig = plt.figure()
res = stats.probplot(price_log, plot=plt)
plt.xlabel('Теоретические квантили')
plt.ylabel('Эмпирические квантили')
plt.title('QQ-график для логарифмированных цен')
plt.show()
# Out:
# mu = 214138.86 and sigma = 92867.65

# %% [markdown]
# ### Распределение переменной "HouseYear" (по годам строительства домов)

# %%
plt.figure(figsize=(18, 6))
sns.barplot(x=train['HouseYear'], y=train['Price'])
plt.xticks(rotation=90)
plt.title('Распределение переменной "HouseYear"')
plt.xlabel('Год постройки')
plt.ylabel('Стоимость')
plt.show()

# %% [markdown]
# ### Распределение переменной "DistrictId" (по идентификаторам районов)

# %%
plt.figure(figsize=(18, 6))
sns.barplot(x=train['DistrictId'], y=train['Price'])
plt.xticks(rotation=90)
plt.title('Распределение переменной "DistrictId"')
plt.xlabel('Идентификатор района')
plt.ylabel('Стоимость')
plt.show()

# %% [markdown]
# ### Особенности проектирования

# %% [markdown]
# #### Отсутствующие данные

# %%
all_data = pd.concat((train, test), sort=False).reset_index(drop=True)
all_data.drop(['Price'], axis=1, inplace=True)
print(f'all_data size is : {all_data.shape}')
# Out:
# all_data size is : (15000, 29)

# %%
all_data_na = (all_data.isnull().sum() / len(all_data)) * 100
all_data_na = all_data_na.drop(
    all_data_na[all_data_na == 0].index).sort_values(ascending=False)
missing_data = pd.DataFrame({'Missing Ratio': all_data_na})
missing_data
# Out:
#                      Missing Ratio
# cluster_year             66.666667
# mean_price_dr            66.666667
# mean_price_by_rooms      66.666667
# large_district           66.666667
# Ecology_2_A              66.666667
# Ecology_2_B              66.666667
# Ecology_3_A              66.666667
# Ecology_3_B              66.666667
# Shops_2_A                66.666667
# Shops_2_B                66.666667
# Healthcare_1             65.320000
# Ecology_2                33.333333
# Ecology_3                33.333333
# Shops_2                  33.333333
# LifeSquare               14.086667

# %%
def df_del_missing(df):
    df_na = (df.isnull().sum() / len(df)) * 100

    df_na = df_na.drop(
        df_na[df_na == 0].index).sort_values(ascending=False)
    df_na = list(df_na.index)
    df.drop(df_na, axis=1, inplace=True)
    return df

# %% [markdown]
# #### Корреляция данных

# %%
corrmat = train.loc[:, train.columns != 'Id'].corr()
plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=0.9, square=True, cmap='inferno')
# Out:
# <AxesSubplot:>

# %%
corrmat = train.loc[:, train.columns != 'Id'].corrwith(
    train['Price']).abs().sort_values(ascending=False)[1:]
plt.bar(corrmat.index, corrmat.values)
plt.title('Корреляция с ценой')
plt.xticks(rotation='vertical')
plt.show()

# %%
train.head()
# Out:
#       Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0  14038          35      2  47.981560   29.442751            6.0      7
# 1  15053          41      3  65.683640   40.049541            8.0      7
# 2   4765          53      2  44.947952   29.197611            0.0      8
# 3   5809          58      2  53.352982   52.731510            9.0      8
# 4  10783          99      1  39.649193   23.776169            7.0     11
#
#    HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 0           9       1969   0.089040         B         B        33      7976
# 1           9       1978   0.000070         B         B        46     10309
# 2          12       1968   0.049637         B         B        34      7759
# 3          17       1977   0.437885         B         B        23      5735
# 4          12       1976   0.012339         B         B        35      5776
#
#    Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2          Price
# 0         5           NaN            0       11       B  184966.937500
# 1         1         240.0            1       16       B  300009.437500
# 2         0         229.0            1        3       B  220925.906250
# 3         3        1084.0            0        5       B  175616.234375
# 4         1        2078.0            2        4       B  150226.531250

# %% [markdown]
# #### Подготовка данных для кластеризации, кластеризация с использованием метода K-Means и визуализацию результатов для определения оптимального количества кластеров.

# %%
scaler = MinMaxScaler()

# %%
train_cluster = train.copy()

# %%
train_cluster = df_fix_house_year_manual(train_cluster)

# %%
train_cluster_scaled = pd.DataFrame(scaler.fit_transform(
    train_cluster.loc[:, ['HouseYear', 'Price']]), columns=['HouseYear', 'Price'])

# %%
inertias = []

for i in range(2, 10):
    temp_model = KMeans(n_clusters=i, random_state=100)
    temp_model.fit(train_cluster_scaled)
    temp_inertia = temp_model.inertia_
    inertias.append(temp_inertia)

plt.plot(range(2, 10), inertias)
plt.title('Инерция')

plt.show()

# %%
plt.scatter(train_cluster_scaled['HouseYear'], train_cluster_scaled['Price'])
plt.xlabel('Год постройки')
plt.ylabel('Стоимость')
plt.show()

# %%
kmeans_model = KMeans(n_clusters=5, random_state=100)

# %%
train_labels = kmeans_model.fit_predict(train_cluster_scaled)

# %%
plt.scatter(train_cluster_scaled['HouseYear'],
            train_cluster_scaled['Price'], c=train_labels)

plt.xlabel('Год постройки дома')
plt.ylabel('Цена')
plt.title('Обучающие данные (результаты кластеризации K-Means)')
# Out:
# Text(0.5, 1.0, 'Обучающие данные (результаты кластеризации K-Means)')

# %%
agglomerative_clustering_model = AgglomerativeClustering(n_clusters=5)

# %%
train_cluster['cluster_year'] = agglomerative_clustering_model.fit_predict(
    train_cluster_scaled)

# %%
plt.scatter(train_cluster['HouseYear'],
            train_cluster['Price'], c=train_cluster['cluster_year'])
plt.xlabel('Год постройки дома')
plt.ylabel('Цена')
plt.title('Обучающие данные (кластеризация Agglomerative Clustering)')
# Out:
# Text(0.5, 1.0, 'Обучающие данные (кластеризация Agglomerative Clustering)')

# %%
def add_cluster_year(df):
    df_scaled = pd.DataFrame(scaler.fit_transform(
        df.loc[:, ['HouseYear']]), columns=['HouseYear'])
    df['cluster_year'] = agglomerative_clustering_model.fit_predict(df_scaled)
    return df

# %% [markdown]
# #### Средняя цена по количеству комнат и средняя цена по идентификатору района и количеству комнат

# %%
def add_mean_price(df, df_train=train):
    price = df_train['Price'].mean()
    price_mean_by_rooms = df_train.groupby(['Rooms'], as_index=False).agg({'Price': 'mean'}).\
        rename(columns={'Price': 'mean_price_by_rooms'})

    price_mean_by_distr_rooms = df_train.groupby(['DistrictId', 'Rooms'], as_index=False).agg({'Price': 'mean'}).\
        rename(columns={'Price': 'mean_price_dr'})

    df = pd.merge(df, price_mean_by_distr_rooms, on=[
                  'DistrictId', 'Rooms'], how='left')
    df = pd.merge(df, price_mean_by_rooms, on='Rooms', how='left')
    df['mean_price_dr'] = df['mean_price_dr'].fillna(df['mean_price_by_rooms'])
    df['mean_price_dr'] = df['mean_price_dr'].fillna(price)
    df['mean_price_by_rooms'] = df['mean_price_by_rooms'].fillna(price)
    return df

# %% [markdown]
# #### Добавление информации о размере района

# %%
def add_distr_info(df):
    distr_info = df['DistrictId'].value_counts().reset_index().\
        rename(columns={"index": "DistrictId", "DistrictId": 'large_district'})
    df = pd.merge(df, distr_info, on='DistrictId', how='left')
    df['large_district'] = df['large_district'].fillna(1)
    return df

# %% [markdown]
# ## Моделирование

# %% [markdown]
# ### Функции

# %%
def data_prepare(df, df_train=train):
    df = df_fix_square_manual(df)
    df = df_fix_house_year_manual(df)
    df = df_fix_room(df)
    df = df_fix_square(df)
    df = prepare_lifesquare(df)
    df = fillna_life_square(df)
    df = df_del_missing(df)
    df = add_cluster_year(df)
    df = add_mean_price(df, df_train)
    df = add_distr_info(df)
    df = pd.get_dummies(df)
    df.drop('mean_square_per_room_in_dr', axis=1, inplace=True)
    df.drop('mean_square_rooms_dr', axis=1, inplace=True)
    optimizing_df(df)
    return df


def model_test(model, name, test, valid):
    model_pred = model.predict(test)
    r2 = r2_score(valid, model_pred)
    mse = mean_squared_error(valid, model_pred)
    plt.scatter(valid, (model_pred - valid))
    plt.xlabel("Predicted values")
    plt.ylabel("Real values")
    plt.title(name)
    plt.legend([f'R2= {r2:.4f} and mse= {mse:.0e}'])
    plt.axhline(0, color='red')
    plt.show()


def model_top_deviation(model, test, valid):
    model_pred = model.predict(test)
    model_test = test.copy()
    model_test['Price'] = model_pred
    model_test['Price_test'] = valid
    model_test['SD'] = abs(model_test['Price']
                           - model_test['Price_test'])
    return model_test.nlargest(10, 'SD')

# %% [markdown]
# ### Загрузка пакетов

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LassoCV
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

from sklearn.model_selection import GridSearchCV

from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

from sklearn.model_selection import train_test_split

# %% [markdown]
# ###  Обработка данных

# %%
print(train.columns)
# Out:
# Index(['Id', 'DistrictId', 'Rooms', 'Square', 'LifeSquare', 'KitchenSquare',
#        'Floor', 'HouseFloor', 'HouseYear', 'Ecology_1', 'Ecology_2',
#        'Ecology_3', 'Social_1', 'Social_2', 'Social_3', 'Healthcare_1',
#        'Helthcare_2', 'Shops_1', 'Shops_2', 'Price'],
#       dtype='object')

# %%
features = list(train.loc[:, train.columns != 'Id'].corrwith(
    train['Price']).abs().sort_values(ascending=False)[1:].index)

target = 'Price'

# %%
train[features].head()
# Out:
#    Rooms     Square  DistrictId  Social_1  Helthcare_2  Social_2  Shops_1  \
# 0      2  47.981560          35        33            0      7976       11
# 1      3  65.683640          41        46            1     10309       16
# 2      2  44.947952          53        34            1      7759        3
# 3      2  53.352982          58        23            0      5735        5
# 4      1  39.649193          99        35            2      5776        4
#
#    Healthcare_1  Floor  HouseFloor  LifeSquare  Social_3  Ecology_1  \
# 0           NaN      7           9   29.442751         5   0.089040
# 1         240.0      7           9   40.049541         1   0.000070
# 2         229.0      8          12   29.197611         0   0.049637
# 3        1084.0      8          17   52.731510         3   0.437885
# 4        2078.0     11          12   23.776169         1   0.012339
#
#    KitchenSquare  HouseYear
# 0            6.0       1969
# 1            8.0       1978
# 2            0.0       1968
# 3            9.0       1977
# 4            7.0       1976

# %%
models_dict = {}

# %%
X_train, X_test, y_train, y_test = train_test_split(
    train[features], train[target], test_size=0.3, random_state=42)

# %%
X_train = data_prepare(X_train, train)
X_test = data_prepare(X_test, train)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7000 entries, 0 to 6999
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Rooms                7000 non-null   uint8
#  1   Square               7000 non-null   float32
#  2   DistrictId           7000 non-null   uint8
#  3   Social_1             7000 non-null   uint8
#  4   Helthcare_2          7000 non-null   uint8
#  5   Social_2             7000 non-null   uint16
#  6   Shops_1              7000 non-null   uint8
#  7   Floor                7000 non-null   uint8
#  8   HouseFloor           7000 non-null   uint8
#  9   LifeSquare           7000 non-null   float32
#  10  Social_3             7000 non-null   uint8
#  11  Ecology_1            7000 non-null   float32
#  12  KitchenSquare        7000 non-null   float32
#  13  HouseYear            7000 non-null   uint16
#  14  cluster_year         7000 non-null   uint8
#  15  mean_price_dr        7000 non-null   float32
#  16  mean_price_by_rooms  7000 non-null   float32
#  17  large_district       7000 non-null   uint16
# dtypes: float32(6), uint16(3), uint8(9)
# memory usage: 321.3 KB

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3000 entries, 0 to 2999
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Rooms                3000 non-null   uint8
#  1   Square               3000 non-null   float32
#  2   DistrictId           3000 non-null   uint8
#  3   Social_1             3000 non-null   uint8
#  4   Helthcare_2          3000 non-null   uint8
#  5   Social_2             3000 non-null   uint16
#  6   Shops_1              3000 non-null   uint8
#  7   Floor                3000 non-null   uint8
#  8   HouseFloor           3000 non-null   uint8
#  9   LifeSquare           3000 non-null   float32
#  10  Social_3             3000 non-null   uint8
#  11  Ecology_1            3000 non-null   float32
#  12  KitchenSquare        3000 non-null   float32
#  13  HouseYear            3000 non-null   uint16
#  14  cluster_year         3000 non-null   uint8
#  15  mean_price_dr        3000 non-null   float32
#  16  mean_price_by_rooms  3000 non-null   float32
#  17  large_district       3000 non-null   uint16
# dtypes: float32(6), uint16(3), uint8(9)
# memory usage: 137.7 KB

# %%
X_train.head()
# Out:
#    Rooms      Square  DistrictId  Social_1  Helthcare_2  Social_2  Shops_1  \
# 0      1   41.681381          23         6            0      1437        2
# 1      3  163.495331          23         2            0       475        0
# 2      1   39.710133          87        43            1      7227        6
# 3      3   96.056786          48        46            1      9515       10
# 4      3   79.195824          77        16            1      4048        3
#
#    Floor  HouseFloor  LifeSquare  Social_3  Ecology_1  KitchenSquare  \
# 0     14          17   22.796165         3   0.075779            8.0
# 1      5           3  161.504227         0   0.014073           12.0
# 2      4          17   19.538664         0   0.100456            8.0
# 3     15           1   96.056786         5   0.041125            1.0
# 4     16          17   44.421062         3   0.298205           10.0
#
#    HouseYear  cluster_year  mean_price_dr  mean_price_by_rooms  large_district
# 0       2015             1  100961.812500        159850.796875             394
# 1       1977             4  170912.203125        289337.968750             394
# 2       1986             2  173074.250000        159850.796875              21
# 3       2017             1  398124.250000        289337.968750              62
# 4       1984             2  250388.140625        289337.968750              28

# %%
y_train.head()
# Out:
# 9069     88504.382812
# 2603    207007.953125
# 7738    182126.281250
# 1579    524365.562500
# 5058    322048.437500
# Name: Price, dtype: float32

# %% [markdown]
# ### Линейная регрессия

# %%
line_regression_model = LinearRegression()
line_regression_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
models_dict['Linear Regression'] = line_regression_model

# %% [markdown]
# #### Тестирование линейной регрессии

# %%
model_test(line_regression_model, 'Linear Regression', X_test, y_test)

# %%
model_top_deviation(line_regression_model, X_test, y_test)
# Out:
#       Rooms      Square  DistrictId  Social_1  Helthcare_2  Social_2  Shops_1  \
# 23        1   47.347305          23         2            0       475        0
# 2299      5  275.645294          86        31            3      7010        7
# 1918      1   46.869541           1         1            0       264        1
# 2439      1   39.709106           6         5            0      1564        0
# 2094      4   98.385445          69        33            1      6783        9
# 350       3  126.621361          24        50            2     12238        3
# 1233      1   42.475578          27         4            0       915        0
# 1957      5  117.855972         169        18            1      3594        5
# 511       1   43.613430           6         5            0      1564        0
# 1298      3   66.674217         137        23            2      3975        0
#
#       Floor  HouseFloor  LifeSquare  ...  Ecology_1  KitchenSquare  HouseYear  \
# 23        7           9   35.936565  ...   0.014073            1.0       1977
# 2299     12          37  233.949310  ...   0.161976           26.0       2011
# 1918     16          24   35.936565  ...   0.007122            1.0       1977
# 2439     10          25    1.836365  ...   0.243205            1.0       2017
# 2094     14          22   76.081772  ...   0.000991            9.0       1979
# 350      22          48   62.455482  ...   0.111627           12.0       2011
# 1233     12          20   35.936565  ...   0.011654           10.0       1977
# 1957     12          14   76.561317  ...   0.178917            9.0       2001
# 511       3          17    3.668460  ...   0.243205            1.0       2016
# 1298      8          10   43.174759  ...   0.200147            9.0       1954
#
#       cluster_year  mean_price_dr  mean_price_by_rooms  large_district  \
# 23               2  100961.812500        159850.796875             171
# 2299             3  382784.968750        410431.593750               5
# 1918             2  147454.609375        159850.796875             186
# 2439             3  135294.171875        159850.796875             156
# 2094             4  500774.125000        383251.093750               8
# 350              3  361843.250000        289337.968750              12
# 1233             2  122710.742188        159850.796875             277
# 1957             1  608674.125000        410431.593750               7
# 511              3  135294.171875        159850.796875             156
# 1298             0  475467.500000        289337.968750               3
#
#              Price     Price_test            SD
# 23    103136.00000  571069.062500  467933.06250
# 2299  698141.00000  264213.562500  433927.43750
# 1918  160683.12500  594565.312500  433882.18750
# 2439  137899.68750  556931.562500  419031.87500
# 2094  496922.15625   91775.320312  405146.84375
# 350   495759.96875  100226.367188  395533.59375
# 1233  125662.00000  514137.343750  388475.34375
# 1957  614437.37500  226513.890625  387923.50000
# 511   131958.53125  518952.656250  386994.12500
# 1298  447937.15625   91325.367188  356611.78125
#
# [10 rows x 21 columns]

# %% [markdown]
# ### Регрессия Random Forest

# %%
random_forest_regressor_model = RandomForestRegressor()
random_forest_regressor_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
models_dict['Random Forest Regressor'] = random_forest_regressor_model

# %% [markdown]
# #### Тестирование регрессии Random Forest

# %%
model_test(random_forest_regressor_model,
           'Random Forest Regressor', X_test, y_test)

# %%
model_top_deviation(random_forest_regressor_model, X_test, y_test)
# Out:
#       Rooms      Square  DistrictId  Social_1  Helthcare_2  Social_2  Shops_1  \
# 23        1   47.347305          23         2            0       475        0
# 1918      1   46.869541           1         1            0       264        1
# 2439      1   39.709106           6         5            0      1564        0
# 350       3  126.621361          24        50            2     12238        3
# 1233      1   42.475578          27         4            0       915        0
# 2094      4   98.385445          69        33            1      6783        9
# 511       1   43.613430           6         5            0      1564        0
# 461       3   68.746971          23         0            0       168        0
# 866       1   40.043236           6         5            0      1564        0
# 476       3   91.948654          59        37            5      7687        5
#
#       Floor  HouseFloor  LifeSquare  ...  Ecology_1  KitchenSquare  HouseYear  \
# 23        7           9   35.936565  ...   0.014073            1.0       1977
# 1918     16          24   35.936565  ...   0.007122            1.0       1977
# 2439     10          25    1.836365  ...   0.243205            1.0       2017
# 350      22          48   62.455482  ...   0.111627           12.0       2011
# 1233     12          20   35.936565  ...   0.011654           10.0       1977
# 2094     14          22   76.081772  ...   0.000991            9.0       1979
# 511       3          17    3.668460  ...   0.243205            1.0       2016
# 461      12          17   64.210121  ...   0.034656            1.0       2017
# 866       3          17   40.043236  ...   0.243205            1.0       2014
# 476      15          20    4.575279  ...   0.019509            1.0       2014
#
#       cluster_year  mean_price_dr  mean_price_by_rooms  large_district  \
# 23               2  100961.812500        159850.796875             171
# 1918             2  147454.609375        159850.796875             186
# 2439             3  135294.171875        159850.796875             156
# 350              3  361843.250000        289337.968750              12
# 1233             2  122710.742188        159850.796875             277
# 2094             4  500774.125000        383251.093750               8
# 511              3  135294.171875        159850.796875             156
# 461              3  170912.203125        289337.968750             171
# 866              3  135294.171875        159850.796875             156
# 476              3  400943.031250        289337.968750              20
#
#               Price     Price_test             SD
# 23    110060.302187  571069.062500  461008.760313
# 1918  154599.583594  594565.312500  439965.728906
# 2439  132613.267500  556931.562500  424318.295000
# 350   498603.515000  100226.367188  398377.147813
# 1233  116398.713984  514137.343750  397738.629766
# 2094  484134.772188   91775.320312  392359.451875
# 511   135446.472109  518952.656250  383506.184141
# 461   128782.410859  497573.375000  368790.964141
# 866   122328.412422  474624.218750  352295.806328
# 476   511731.213125  166076.546875  345654.666250
#
# [10 rows x 21 columns]

# %% [markdown]
# ### Градиентный спуск

# %%
gradient_boosting_regressor_model = GradientBoostingRegressor()
gradient_boosting_regressor_model.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor()

# %%
models_dict['Gradient Boosting Regressor'] = gradient_boosting_regressor_model

# %% [markdown]
# #### Тестирование градиентного спуска

# %%
model_test(gradient_boosting_regressor_model,
           'Gradient Boosting Regressor', X_test, y_test)

# %%
model_top_deviation(gradient_boosting_regressor_model, X_test, y_test)
# Out:
#       Rooms      Square  DistrictId  Social_1  Helthcare_2  Social_2  Shops_1  \
# 23        1   47.347305          23         2            0       475        0
# 1918      1   46.869541           1         1            0       264        1
# 350       3  126.621361          24        50            2     12238        3
# 2439      1   39.709106           6         5            0      1564        0
# 2094      4   98.385445          69        33            1      6783        9
# 511       1   43.613430           6         5            0      1564        0
# 1233      1   42.475578          27         4            0       915        0
# 1298      3   66.674217         137        23            2      3975        0
# 866       1   40.043236           6         5            0      1564        0
# 36        4  105.436317          46        31            0      6137        1
#
#       Floor  HouseFloor  LifeSquare  ...  Ecology_1  KitchenSquare  HouseYear  \
# 23        7           9   35.936565  ...   0.014073            1.0       1977
# 1918     16          24   35.936565  ...   0.007122            1.0       1977
# 350      22          48   62.455482  ...   0.111627           12.0       2011
# 2439     10          25    1.836365  ...   0.243205            1.0       2017
# 2094     14          22   76.081772  ...   0.000991            9.0       1979
# 511       3          17    3.668460  ...   0.243205            1.0       2016
# 1233     12          20   35.936565  ...   0.011654           10.0       1977
# 1298      8          10   43.174759  ...   0.200147            9.0       1954
# 866       3          17   40.043236  ...   0.243205            1.0       2014
# 36       23          22   68.823044  ...   0.188784           10.0       1998
#
#       cluster_year  mean_price_dr  mean_price_by_rooms  large_district  \
# 23               2  100961.812500        159850.796875             171
# 1918             2  147454.609375        159850.796875             186
# 350              3  361843.250000        289337.968750              12
# 2439             3  135294.171875        159850.796875             156
# 2094             4  500774.125000        383251.093750               8
# 511              3  135294.171875        159850.796875             156
# 1233             2  122710.742188        159850.796875             277
# 1298             0  475467.500000        289337.968750               3
# 866              3  135294.171875        159850.796875             156
# 36               1  375229.687500        383251.093750              35
#
#               Price     Price_test             SD
# 23    121733.656538  571069.062500  449335.405962
# 1918  148311.298204  594565.312500  446254.014296
# 350   541190.460894  100226.367188  440964.093707
# 2439  129663.330118  556931.562500  427268.232382
# 2094  490493.845866   91775.320312  398718.525553
# 511   124653.317740  518952.656250  394299.338510
# 1233  124791.374716  514137.343750  389345.969034
# 1298  461995.150147   91325.367188  370669.782959
# 866   121169.190716  474624.218750  353455.028034
# 36    449026.318154  103510.226562  345516.091592
#
# [10 rows x 21 columns]

# %% [markdown]
# ### Метод Lasso со встроенной кросс-валидацией

# %%
lasso_cv_model = LassoCV()
lasso_cv_model.fit(X_train, y_train)
# Out:
# LassoCV()

# %%
models_dict['LassoCV'] = lasso_cv_model

# %% [markdown]
# #### Тестирование LassoCV

# %%
model_test(lasso_cv_model, 'LassoCV', X_test, y_test)

# %%
model_top_deviation(lasso_cv_model, X_test, y_test)
# Out:
#       Rooms      Square  DistrictId  Social_1  Helthcare_2  Social_2  Shops_1  \
# 23        1   47.347305          23         2            0       475        0
# 1918      1   46.869541           1         1            0       264        1
# 2439      1   39.709106           6         5            0      1564        0
# 2094      4   98.385445          69        33            1      6783        9
# 1233      1   42.475578          27         4            0       915        0
# 1298      3   66.674217         137        23            2      3975        0
# 511       1   43.613430           6         5            0      1564        0
# 1957      5  117.855972         169        18            1      3594        5
# 866       1   40.043236           6         5            0      1564        0
# 465       3  120.771217          27         2            0       629        0
#
#       Floor  HouseFloor  LifeSquare  ...  Ecology_1  KitchenSquare  HouseYear  \
# 23        7           9   35.936565  ...   0.014073            1.0       1977
# 1918     16          24   35.936565  ...   0.007122            1.0       1977
# 2439     10          25    1.836365  ...   0.243205            1.0       2017
# 2094     14          22   76.081772  ...   0.000991            9.0       1979
# 1233     12          20   35.936565  ...   0.011654           10.0       1977
# 1298      8          10   43.174759  ...   0.200147            9.0       1954
# 511       3          17    3.668460  ...   0.243205            1.0       2016
# 1957     12          14   76.561317  ...   0.178917            9.0       2001
# 866       3          17   40.043236  ...   0.243205            1.0       2014
# 465       8           1  118.048981  ...   0.072158            1.0       1977
#
#       cluster_year  mean_price_dr  mean_price_by_rooms  large_district  \
# 23               2  100961.812500        159850.796875             171
# 1918             2  147454.609375        159850.796875             186
# 2439             3  135294.171875        159850.796875             156
# 2094             4  500774.125000        383251.093750               8
# 1233             2  122710.742188        159850.796875             277
# 1298             0  475467.500000        289337.968750               3
# 511              3  135294.171875        159850.796875             156
# 1957             1  608674.125000        410431.593750               7
# 866              3  135294.171875        159850.796875             156
# 465              2  214083.593750        289337.968750             277
#
#               Price     Price_test            SD
# 23    101303.382812  571069.062500  469765.68750
# 1918  147666.421875  594565.312500  446898.87500
# 2439  135539.921875  556931.562500  421391.62500
# 2094  499999.843750   91775.320312  408224.53125
# 1233  122991.609375  514137.343750  391145.75000
# 1298  474763.843750   91325.367188  383438.46875
# 511   135539.921875  518952.656250  383412.75000
# 1957  607598.750000  226513.890625  381084.87500
# 866   135539.921875  474624.218750  339084.31250
# 465   214109.453125  547434.937500  333325.50000
#
# [10 rows x 21 columns]

# %%
all_data.loc[all_data['KitchenSquare'] < 3]
# Out:
#           Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 2       4765          53      2  44.947952   29.197611            0.0      8
# 7      11993          74      2  80.312927         NaN            0.0     14
# 8       5172           1      2  64.511436         NaN            1.0      9
# 12      6452          13      2  54.522804   31.759752            1.0      8
# 14     10953          27      1  53.769096   52.408028            1.0      5
# ...      ...         ...    ...        ...         ...            ...    ...
# 14982  12920          23      1  39.610428   38.187572            1.0      6
# 14985  11732           1      1  46.597282         NaN            1.0     17
# 14987   5361          53      3  80.102104         NaN            1.0     13
# 14998   4780          62      2  81.305222         NaN            0.0      4
# 14999  12504          30      2  60.555695         NaN            1.0     10
#
#        HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 2              12       1968   0.049637         B         B        34
# 7               0       1977   0.075779         B         B         6
# 8              17       1977   0.007122         B         B         1
# 12             12       1999   0.090799         B         B        74
# 14              4       1977   0.072158         B         B         2
# ...           ...        ...        ...       ...       ...       ...
# 14982          18       2013   0.034656         B         B         0
# 14985          24       1977   0.007122         B         B         1
# 14987          22       1977   0.049637         B         B        34
# 14998           0       1977   0.072158         B         B         2
# 14999          17       1977   0.000078         B         B        22
#
#        Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 2          7759         0         229.0            1        3       B
# 7          1437         3           NaN            0        2       B
# 8           264         0           NaN            0        1       B
# 12        19083         2           NaN            5       15       B
# 14          629         1           NaN            0        0       A
# ...         ...       ...           ...          ...      ...     ...
# 14982       168         0           NaN            0        0       B
# 14985       264         0           NaN            0        1       B
# 14987      7759         0         229.0            1        3       B
# 14998       629         1           NaN            0        0       A
# 14999      6398       141        1046.0            3       23       B
#
# [4691 rows x 19 columns]

# %% [markdown]
# ### Алгоритм градиентного бустинга на деревьях решений для задач регрессии (LGBMRegressor)

# %%
lgbm_regressor_model = LGBMRegressor()
lgbm_regressor_model.fit(X_train, y_train)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000730 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1596
# [LightGBM] [Info] Number of data points in the train set: 7000, number of used features: 18
# [LightGBM] [Info] Start training from score 214449.167251
# LGBMRegressor()

# %% [markdown]
# #### Тестрирование LGBMRegressor

# %%
model_test(lgbm_regressor_model, 'LGBMRegressor', X_test, y_test)

# %%
model_top_deviation(lgbm_regressor_model, X_test, y_test)
# Out:
#       Rooms     Square  DistrictId  Social_1  Helthcare_2  Social_2  Shops_1  \
# 23        1  47.347305          23         2            0       475        0
# 1918      1  46.869541           1         1            0       264        1
# 2094      4  98.385445          69        33            1      6783        9
# 2439      1  39.709106           6         5            0      1564        0
# 1233      1  42.475578          27         4            0       915        0
# 511       1  43.613430           6         5            0      1564        0
# 1298      3  66.674217         137        23            2      3975        0
# 461       3  68.746971          23         0            0       168        0
# 866       1  40.043236           6         5            0      1564        0
# 1659      3  85.887405          17        25            1      5027        1
#
#       Floor  HouseFloor  LifeSquare  ...  Ecology_1  KitchenSquare  HouseYear  \
# 23        7           9   35.936565  ...   0.014073            1.0       1977
# 1918     16          24   35.936565  ...   0.007122            1.0       1977
# 2094     14          22   76.081772  ...   0.000991            9.0       1979
# 2439     10          25    1.836365  ...   0.243205            1.0       2017
# 1233     12          20   35.936565  ...   0.011654           10.0       1977
# 511       3          17    3.668460  ...   0.243205            1.0       2016
# 1298      8          10   43.174759  ...   0.200147            9.0       1954
# 461      12          17   64.210121  ...   0.034656            1.0       2017
# 866       3          17   40.043236  ...   0.243205            1.0       2014
# 1659      8           8   60.230133  ...   0.000000            9.0       1960
#
#       cluster_year  mean_price_dr  mean_price_by_rooms  large_district  \
# 23               2  100961.812500        159850.796875             171
# 1918             2  147454.609375        159850.796875             186
# 2094             4  500774.125000        383251.093750               8
# 2439             3  135294.171875        159850.796875             156
# 1233             2  122710.742188        159850.796875             277
# 511              3  135294.171875        159850.796875             156
# 1298             0  475467.500000        289337.968750               3
# 461              3  170912.203125        289337.968750             171
# 866              3  135294.171875        159850.796875             156
# 1659             0  419768.781250        289337.968750              22
#
#               Price     Price_test             SD
# 23    115252.418641  571069.062500  455816.643859
# 1918  152136.509010  594565.312500  442428.803490
# 2094  520873.172210   91775.320312  429097.851897
# 2439  132130.004850  556931.562500  424801.557650
# 1233  118221.165946  514137.343750  395916.177804
# 511   126887.371718  518952.656250  392065.284532
# 1298  470494.104574   91325.367188  379168.737386
# 461   143036.557777  497573.375000  354536.817223
# 866   120228.654295  474624.218750  354395.564455
# 1659  497492.355500  143194.062500  354298.293000
#
# [10 rows x 21 columns]

# %% [markdown]
# #### Настройка LGBMRegressor

# %%
lgbm_regressor_model.get_params
# Out:
# <bound method LGBMModel.get_params of LGBMRegressor()>

# %%
np.arange(0.01, 0.05, 0.01)
# Out:
# array([0.01, 0.02, 0.03, 0.04])

# %%
parameters = [{
    'max_bin': np.arange(90, 120, 10),
    'n_estimators': np.arange(4000, 7000, 1000),
    'learning_rate': np.arange(0.01, 0.05, 0.01)
}]

# %%
clf = GridSearchCV(
    estimator=LGBMRegressor(random_state=42),
    param_grid=parameters,
    scoring='neg_mean_squared_error',
    cv=4,
    n_jobs=-1,
)

# %%
clf.fit(X_train, y_train)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000727 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1011
# [LightGBM] [Info] Number of data points in the train set: 7000, number of used features: 18
# [LightGBM] [Info] Start training from score 214449.167251
# GridSearchCV(cv=4, estimator=LGBMRegressor(random_state=42), n_jobs=-1,
#              param_grid=[{'learning_rate': array([0.01, 0.02, 0.03, 0.04]),
#                           'max_bin': array([ 90, 100, 110]),
#                           'n_estimators': array([4000, 5000, 6000])}],
#              scoring='neg_mean_squared_error')

# %%
cv_results = pd.DataFrame(clf.cv_results_)
param_columns = [
    column
    for column in cv_results.columns
    if column.startswith('param_')
]

score_columns = ['mean_test_score']

cv_results = (cv_results[param_columns + score_columns]
              .sort_values(by=score_columns, ascending=False))

cv_results.head(10)
# Out:
#    param_learning_rate param_max_bin param_n_estimators  mean_test_score
# 6                 0.01           110               4000    -2.025945e+09
# 3                 0.01           100               4000    -2.045600e+09
# 7                 0.01           110               5000    -2.050298e+09
# 0                 0.01            90               4000    -2.056559e+09
# 4                 0.01           100               5000    -2.066629e+09
# 8                 0.01           110               6000    -2.070852e+09
# 1                 0.01            90               5000    -2.076620e+09
# 15                0.02           110               4000    -2.087484e+09
# 5                 0.01           100               6000    -2.087922e+09
# 2                 0.01            90               6000    -2.093438e+09

# %%
clf.best_params_
# Out:
# {'learning_rate': 0.01, 'max_bin': 110, 'n_estimators': 4000}

# %% [markdown]
# #### Тестирование настроенной LGBMRegressor

# %%
lgbm_regressor_model = LGBMRegressor(
    max_bin=110,
    num_leaves=4,
    n_estimators=4000,
    learning_rate=0.01
)
lgbm_regressor_model.fit(X_train, y_train)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001367 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1011
# [LightGBM] [Info] Number of data points in the train set: 7000, number of used features: 18
# [LightGBM] [Info] Start training from score 214449.167251
# LGBMRegressor(learning_rate=0.01, max_bin=110, n_estimators=4000, num_leaves=4)

# %%
model_test(lgbm_regressor_model, 'LGBMRegressor', X_test, y_test)

# %%
models_dict['LGBMRegressor'] = lgbm_regressor_model

# %% [markdown]
# ### Алгоритм градиентного бустинга на деревьях решений для задач регрессии (XGBRegressor)

# %%
xgboost_model = XGBRegressor()
xgboost_model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
models_dict['XGBRegressor'] = xgboost_model

# %% [markdown]
# #### Тестирование XGBRegressor

# %%
model_test(xgboost_model, 'XGBRegressor', X_test, y_test)

# %%
model_top_deviation(xgboost_model, X_test, y_test)
# Out:
#       Rooms      Square  DistrictId  Social_1  Helthcare_2  Social_2  Shops_1  \
# 2094      4   98.385445          69        33            1      6783        9
# 350       3  126.621361          24        50            2     12238        3
# 23        1   47.347305          23         2            0       475        0
# 1918      1   46.869541           1         1            0       264        1
# 2439      1   39.709106           6         5            0      1564        0
# 1298      3   66.674217         137        23            2      3975        0
# 1233      1   42.475578          27         4            0       915        0
# 511       1   43.613430           6         5            0      1564        0
# 1659      3   85.887405          17        25            1      5027        1
# 461       3   68.746971          23         0            0       168        0
#
#       Floor  HouseFloor  LifeSquare  ...  Ecology_1  KitchenSquare  HouseYear  \
# 2094     14          22   76.081772  ...   0.000991            9.0       1979
# 350      22          48   62.455482  ...   0.111627           12.0       2011
# 23        7           9   35.936565  ...   0.014073            1.0       1977
# 1918     16          24   35.936565  ...   0.007122            1.0       1977
# 2439     10          25    1.836365  ...   0.243205            1.0       2017
# 1298      8          10   43.174759  ...   0.200147            9.0       1954
# 1233     12          20   35.936565  ...   0.011654           10.0       1977
# 511       3          17    3.668460  ...   0.243205            1.0       2016
# 1659      8           8   60.230133  ...   0.000000            9.0       1960
# 461      12          17   64.210121  ...   0.034656            1.0       2017
#
#       cluster_year  mean_price_dr  mean_price_by_rooms  large_district  \
# 2094             4  500774.125000        383251.093750               8
# 350              3  361843.250000        289337.968750              12
# 23               2  100961.812500        159850.796875             171
# 1918             2  147454.609375        159850.796875             186
# 2439             3  135294.171875        159850.796875             156
# 1298             0  475467.500000        289337.968750               3
# 1233             2  122710.742188        159850.796875             277
# 511              3  135294.171875        159850.796875             156
# 1659             0  419768.781250        289337.968750              22
# 461              3  170912.203125        289337.968750             171
#
#               Price     Price_test           SD
# 2094  560027.000000   91775.320312  468251.6875
# 350   564489.812500  100226.367188  464263.4375
# 23    112358.765625  571069.062500  458710.3125
# 1918  152078.109375  594565.312500  442487.1875
# 2439  129464.742188  556931.562500  427466.8125
# 1298  495781.687500   91325.367188  404456.3125
# 1233  114103.085938  514137.343750  400034.2500
# 511   134738.671875  518952.656250  384214.0000
# 1659  511480.312500  143194.062500  368286.2500
# 461   131201.562500  497573.375000  366371.8125
#
# [10 rows x 21 columns]

# %% [markdown]
# ## Итоги

# %% [markdown]
# ### Загрузка пакетов

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### Функция

# %%
def models_r2(models, test, valid):
    scores = pd.DataFrame(columns=['name', 'r2', 'mse'])
    for name, model in models.items():
        test_pred = model.predict(test)
        r2 = r2_score(valid, test_pred)
        mse = mean_squared_error(valid, test_pred)
        scores = scores.append(
            {'name': name, 'r2': r2, 'mse': mse}, ignore_index=True)
    scores.sort_values('r2', ascending=False, inplace=True)
    return scores

# %% [markdown]
# ### Выбор лучшей модели

# %%
models_score_test = models_r2(models_dict, X_test, y_test)
models_score_train = models_r2(models_dict, X_train, y_train)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4744\4277186224.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   scores = scores.append(
# C:\Users\User\AppData\Local\Temp\ipykernel_4744\4277186224.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   scores = scores.append(
# C:\Users\User\AppData\Local\Temp\ipykernel_4744\4277186224.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   scores = scores.append(
# C:\Users\User\AppData\Local\Temp\ipykernel_4744\4277186224.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   scores = scores.append(
# C:\Users\User\AppData\Local\Temp\ipykernel_4744\4277186224.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   scores = scores.append(
# C:\Users\User\AppData\Local\Temp\ipykernel_4744\4277186224.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   scores = scores.append(
# C:\Users\User\AppData\Local\Temp\ipykernel_4744\4277186224.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   scores = scores.append(
# C:\Users\User\AppData\Local\Temp\ipykernel_4744\4277186224.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   scores = scores.append(
# C:\Users\User\AppData\Local\Temp\ipykernel_4744\4277186224.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   scores = scores.append(
# C:\Users\User\AppData\Local\Temp\ipykernel_4744\4277186224.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   scores = scores.append(
# C:\Users\User\AppData\Local\Temp\ipykernel_4744\4277186224.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   scores = scores.append(
# C:\Users\User\AppData\Local\Temp\ipykernel_4744\4277186224.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   scores = scores.append(

# %%
models_score_test[['name', 'r2']]
# Out:
#                           name        r2
# 1      Random Forest Regressor  0.754323
# 4                LGBMRegressor  0.754293
# 2  Gradient Boosting Regressor  0.740221
# 5                 XGBRegressor  0.738218
# 0            Linear Regression  0.696287
# 3                      LassoCV  0.628189

# %%
r2_max_test = models_score_test['r2'].max()
r2_max_train = models_score_train['r2'].max()
plt.barh(models_score_test['name'], models_score_test['r2'],
         alpha=0.5, color='blue', label=f'Test  Data: R2 max: {r2_max_test:.4f}')
plt.barh(models_score_train['name'], models_score_train['r2'],
         alpha=0.5, color='grey', label=f'Train Data: R2 max: {r2_max_train:.4f}')
plt.title('R2')
plt.legend()
plt.axvline(0.6, color='red')
plt.axvline(r2_max_test, color='yellow')
plt.show()

# %%
mse_min_test = models_score_test['mse'].min()
mse_min_train = models_score_train['mse'].min()
plt.barh(models_score_test['name'], models_score_test['mse'],
         alpha=0.5, color='green', label=f'Test  Data MSE min: {mse_min_test:.0e}')
plt.barh(models_score_train['name'], models_score_train['mse'],
         alpha=0.5, color='grey', label=f'Train Data MSE min: {mse_min_train:.0e}')
plt.title('Mean squared error')
plt.legend(loc=2)
plt.axvline(mse_min_test, color='yellow')
plt.show()

# %%
best_model = models_dict['LGBMRegressor']

# %%
pd.DataFrame({'name': list(X_train.columns),
              'importances': list(best_model.feature_importances_)})
# Out:
#                    name  importances
# 0                 Rooms          583
# 1                Square         1616
# 2            DistrictId          514
# 3              Social_1          622
# 4           Helthcare_2          105
# 5              Social_2          422
# 6               Shops_1          359
# 7                 Floor          415
# 8            HouseFloor          780
# 9            LifeSquare          455
# 10             Social_3          607
# 11            Ecology_1          878
# 12        KitchenSquare          660
# 13            HouseYear         1185
# 14         cluster_year           92
# 15        mean_price_dr         1750
# 16  mean_price_by_rooms          154
# 17       large_district          803

# %%
model_test(best_model, 'Лучшая модель', X_test, y_test)

# %% [markdown]
# ## Выходные файлы

# %%
test = data_prepare(test)

# %%
test_features = list(X_train.columns)

# %%
test[test_features].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5000 entries, 0 to 4999
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Rooms                5000 non-null   uint8
#  1   Square               5000 non-null   float32
#  2   DistrictId           5000 non-null   uint8
#  3   Social_1             5000 non-null   uint8
#  4   Helthcare_2          5000 non-null   uint8
#  5   Social_2             5000 non-null   uint16
#  6   Shops_1              5000 non-null   uint8
#  7   Floor                5000 non-null   uint8
#  8   HouseFloor           5000 non-null   uint8
#  9   LifeSquare           5000 non-null   float32
#  10  Social_3             5000 non-null   uint8
#  11  Ecology_1            5000 non-null   float32
#  12  KitchenSquare        5000 non-null   float32
#  13  HouseYear            5000 non-null   uint16
#  14  cluster_year         5000 non-null   uint8
#  15  mean_price_dr        5000 non-null   float32
#  16  mean_price_by_rooms  5000 non-null   float32
#  17  large_district       5000 non-null   uint16
# dtypes: float32(6), uint16(3), uint8(9)
# memory usage: 229.5 KB

# %%
test['Price'] = best_model.predict(test[test_features])

# %%
price_log = np.log1p(test['Price'])
sns.histplot(price_log, kde=True)

mu, sigma = norm.fit(test['Price'])

print(f'mu = {mu:.2f} and sigma = {sigma:.2f}')

plt.legend(
    [f'Normal dist. ($\mu=$ {mu:.2f} and $\sigma=$ {sigma:.2f} )'], loc='best')
plt.xlabel('Стоимость')
plt.ylabel('Частота')
plt.title('Распределение цен')

# QQ-plot
fig = plt.figure()
res = stats.probplot(price_log, plot=plt)
plt.xlabel('Теоретические квантили')
plt.ylabel('Упорядоченные значения')
plt.title('Вероятностный график')
plt.show()
# Out:
# mu = 215662.41 and sigma = 78147.05

# %%
test[['Id', 'Price']].to_csv('DMolchanov_predictions.csv', index=None)
